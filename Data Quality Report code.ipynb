# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# read csv file
d1 = pd.read_excel('card transactions.xlsx')

# %%
d1.shape
# Out:
# (96753, 10)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96753 entries, 0 to 96752
# Data columns (total 10 columns):
# Recnum               96753 non-null int64
# Cardnum              96753 non-null int64
# Date                 96753 non-null datetime64[ns]
# Merchnum             93378 non-null object
# Merch description    96753 non-null object
# Merch state          95558 non-null object
# Merch zip            92097 non-null float64
# Transtype            96753 non-null object
# Amount               96753 non-null float64
# Fraud                96753 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 7.4+ MB

# %%
d1.describe()
# Out:
#         Recnum       Cardnum  Merch zip     Amount    Fraud
# count 96753.00      96753.00   92097.00   96753.00 96753.00
# mean  48377.00 5142201786.82   44706.60     427.89     0.01
# std   27930.33      55670.84   28369.54   10006.14     0.10
# min       1.00 5142110002.00       1.00       0.01     0.00
# 25%   24189.00 5142152067.00   20855.00      33.48     0.00
# 50%   48377.00 5142195612.00   38118.00     137.98     0.00
# 75%   72565.00 5142246089.00   63103.00     428.20     0.00
# max   96753.00 5142847398.00   99999.00 3102045.53     1.00

# %%
d1.head()
# Out:
#    Recnum     Cardnum       Date       Merchnum        Merch description  \
# 0       1  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1       2  5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2       3  5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 3       4  5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4       5  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud
# 0          TN    38118.0         P    3.62      0
# 1          MA     1803.0         P   31.42      0
# 2          MD    20706.0         P  178.49      0
# 3          TN    38118.0         P    3.62      0
# 4          TN    38118.0         P    3.62      0

# %%
dict_value_counts = {}
for i in d1.columns.to_list():
    dict_value_counts[i]=d1[i].value_counts()

# %%
dict_value_counts
# Out:
# {'Recnum': 2047     1
#  23198    1
#  661      1
#  6806     1
#  4759     1
#          ..
#  30052    1
#  32101    1
#  25958    1
#  28007    1
#  2049     1
#  Name: Recnum, Length: 96753, dtype: int64, 'Cardnum': 5142148452    1192
#  5142184598     921
#  5142189108     663
#  5142297710     583
#  5142223373     579
#                ...
#  5142163835       1
#  5142173161       1
#  5142245286       1
#  5142265215       1
#  5142261785       1
#  Name: Cardnum, Length: 1645, dtype: int64, 'Date': 2010-02-28    684
#  2010-08-10    610
#  2010-03-15    594
#  2010-09-13    564
#  2010-08-09    536
#               ...
#  2010-11-07     11
#  2010-10-03     10
#  2010-01-16      9
#  2010-10-17      6
#  2010-12-26      6
#  Name: Date, Length: 365, dtype: int64, 'Merchnum': 930090121224     9310
#  5509006296254    2131
#  9900020006406    1714
#  602608969534     1092
#  4353000719908    1020
#                   ...
#  971965              1
#  66006411336         1
#  3500000008981       1
#  7534660098362       1
#  9983030046945       1
#  Name: Merchnum, Length: 13091, dtype: int64, 'Merch description': GSA-FSS-ADV               1688
#  SIGMA-ALDRICH             1635
#  STAPLES #941              1174
#  FISHER SCI ATL            1093
#  MWI*MICRO WAREHOUSE        958
#                            ...
#  DI RALEIGH                   1
#  CRANBERRY COMPUTER           1
#  NATL COUNCIL ON RADIAT       1
#  WOLF CAMERA #249             1
#  RAMADA INN HTL               1
#  Name: Merch description, Length: 13126, dtype: int64, 'Merch state': TN     12035
#  VA      7872
#  CA      6817
#  IL      6508
#  MD      5398
#         ...
#  016        1
#  461        1
#  279        1
#  269        1
#  924        1
#  Name: Merch state, Length: 227, dtype: int64, 'Merch zip': 38118.0    11868
#  63103.0     1650
#  8701.0      1267
#  22202.0     1250
#  60061.0     1221
#             ...
#  90740.0        1
#  45365.0        1
#  14604.0        1
#  74401.0        1
#  5.0            1
#  Name: Merch zip, Length: 4567, dtype: int64, 'Transtype': P    96398
#  A      181
#  D      173
#  Y        1
#  Name: Transtype, dtype: int64, 'Amount': 3.62       4283
#  3.67       1620
#  3.74        913
#  3.80        827
#  4.37        378
#             ...
#  201.09        1
#  1394.50       1
#  197.73        1
#  282.93        1
#  120.67        1
#  Name: Amount, Length: 34909, dtype: int64, 'Fraud': 0    95694
#  1     1059
#  Name: Fraud, dtype: int64}

# %%
sns.heatmap(d1.isnull(),cbar=False)

# %%
dict_unique = {}
for i in d1.columns.to_list():
    dict_unique[i]=len(d1[i].unique())

# %%
dict_unique
# Out:
# {'Recnum': 96753,
#  'Cardnum': 1645,
#  'Date': 365,
#  'Merchnum': 13092,
#  'Merch description': 13126,
#  'Merch state': 228,
#  'Merch zip': 4568,
#  'Transtype': 4,
#  'Amount': 34909,
#  'Fraud': 2}

# %%
dict_populated = {}
for i in d1.columns.to_list():
    dict_populated[i] = d1[i].count()/len(d1)*100

# %%
dict_populated
# Out:
# {'Recnum': 100.0,
#  'Cardnum': 100.0,
#  'Date': 100.0,
#  'Merchnum': 96.51173607019938,
#  'Merch description': 100.0,
#  'Merch state': 98.76489617892985,
#  'Merch zip': 95.1877461163995,
#  'Transtype': 100.0,
#  'Amount': 100.0,
#  'Fraud': 100.0}

# %%
d1[d1['Amount'] == 0]
# Out:
# Empty DataFrame
# Columns: [Recnum, Cardnum, Date, Merchnum, Merch description, Merch state, Merch zip, Transtype, Amount, Fraud]
# Index: []

# %%
d1.tail()
# Out:
#        Recnum     Cardnum       Date       Merchnum       Merch description  \
# 96748   96749  5142276053 2010-12-31  3500000006160  BEST BUY      00001610
# 96749   96750  5142225701 2010-12-31  8090710030950  MARKUS OFFICE SUPPLIES
# 96750   96751  5142226486 2010-12-31  4503057341100           TECH PAC, INC
# 96751   96752  5142244619 2010-12-31  8834000695412                 BUY.COM
# 96752   96753  5142243247 2010-12-31  9108347680006   STAPLES NATIONAL #471
#
#       Merch state  Merch zip Transtype  Amount  Fraud
# 96748          KY   41042.00         P   84.79      0
# 96749          OH   45248.00         P  118.75      0
# 96750          OH   45150.00         P  363.56      0
# 96751          CA   92656.00         P 2202.03      0
# 96752          NJ    7606.00         P  554.64      0

# %%
d2 = d1.drop(['Amount','Recnum'],axis=1)

# %%
for i in d2.columns.to_list():
    d2[i]=d2[i].astype(str)

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96753 entries, 0 to 96752
# Data columns (total 8 columns):
# Cardnum              96753 non-null object
# Date                 96753 non-null object
# Merchnum             96753 non-null object
# Merch description    96753 non-null object
# Merch state          96753 non-null object
# Merch zip            96753 non-null object
# Transtype            96753 non-null object
# Fraud                96753 non-null object
# dtypes: object(8)
# memory usage: 5.9+ MB

# %%
categoricalVar=d2.columns.tolist()
for col in categoricalVar:
    df = pd.DataFrame(d2[col].value_counts().sort_values(ascending=False).head(20))
    df.plot(kind='bar',figsize=(12,6))
    plt.xlabel(col,fontsize=15)
    plt.ylabel('Frequency',fontsize=15)
    plt.xticks(fontsize=12)

# %%
categoricalVar=d2.columns.tolist()
for col in categoricalVar:
    df = pd.DataFrame(d2[col].value_counts().sort_values(ascending=False).head(20))
    df.plot(kind='bar',figsize=(12,6))
    plt.xlabel(col,fontsize=15)
    plt.ylabel('Frequency',fontsize=15)
    plt.xticks(fontsize=12)
    plt.yscale('log')

# %%
plt.rcParams["figure.figsize"] = [12,6]
xhigh = 50000
plt.xlim(0,xhigh)
temp = d1[d1['Amount'] <= xhigh]
sns.set_palette("deep")
plot=sns.distplot(temp['Amount'],bins=25, kde=False, color='blue')
plot.set_yscale('log')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
dict_value_counts['Date'].to_csv('date.csv')
# Out:
# C:\Users\Mrinal Gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
plt.hist(d1['Amount'],bins=50,range=[0,40000],edgecolor='blue',linewidth=1.2)
plt.yscale('log')
plt.ylim(bottom = .1)
plt.ylabel('Count')
plt.xlabel('Amount')
# Out:
# Text(0.5, 0, 'Amount')
